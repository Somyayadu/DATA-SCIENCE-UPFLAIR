# %%
# DEEP LEARNING..... 

# ANN - ARTIFICIAL NEURAL NETWORKS
# Input Layer :- 1ST LAYER ,INPUT DATA IS GIVEN HERE
# Hidden Layer :- 2ND LAYER , HIDDEN LAYER IS USED TO LEARN THE PATTERN
# Output Layer :- 3RD LAYER , OUTPUT IS GIVEN HERE

# BINARY CLASSIFICATION :- CLASSIFYING DATA INTO TWO CATEGORIES
# MULTI CLASS CLASSIFICATION :- CLASSIFYING DATA INTO MORE THAN TWO CATEGORIES

# PERCEPTRON :- A SINGLE LAYER NEURAL NETWORK
# MULTI-LAYER PERCEPTRON :- A NEURAL NETWORK WITH MULTIPLE LAYERS
# W= WEIGHT
# B= BIAS
# Y= OUTPUT
# Z= INPUT TO THE ACTIVATION FUNCTION
# ACTIVATION FUNCTION :- ADD NON LINEARITY FUNCTION TO SOLVE COMPLEX PROBLEMS
# NON LINEARITY :- A FUNCTION THAT IS NOT A STRAIGHT LINE

# TYPES OF ACTIVATION FUNCTIONS
# 1. SIGMOID FUNCTION :- USED FOR BINARY CLASSIFICATION 
# 2. TANH FUNCTION :- USED FOR BINARY CLASSIFICATION
# 3. RELU FUNCTION :- USED FOR MULTI CLASS CLASSIFICATION       
# 4. SOFTMAX FUNCTION :- USED FOR MULTI CLASS CLASSIFICATION
# 5. LINEAR FUNCTION :- USED FOR REGRESSION PROBLEMS
# 6. LEAKY RELU FUNCTION :- USED FOR MULTI CLASS CLASSIFICATION
# 7. SWISH FUNCTION :- USED FOR MULTI CLASS CLASSIFICATION
# 8. GELU FUNCTION :- USED FOR MULTI CLASS CLASSIFICATION
# 9. SOFTPLUS FUNCTION :- USED FOR MULTI CLASS CLASSIFICATION
# 10. SOFTSIGN FUNCTION :- USED FOR MULTI CLASS CLASSIFICATION


# EPOCH :- A SINGLE ITERATION OVER THE ENTIRE DATASET
# OUTPUT RANGE :- THE RANGE OF OUTPUT VALUES
# DERIVATIVE RANGE :- THE RANGE OF DERIVATIVE VALUES

# VANISHING GRADIENT PROBLEM :- A PROBLEM THAT OCCURS WHEN THE GRADIENTS OF THE LOSS FUNCTION BECOME VERY SMALL,
#                               MAKING IT DIFFICULT TO UPDATE THE WEIGHTS OF THE NEURAL NETWORK .

# LOSS FUNCTION ARE USED IN REGRESSION 
# . MEAN SQUARED ERROR 
# . MEAN ABSOLUTE ERROR 
# . HUBER LOSS

# LOSS FUNCTION ARE USED IN CLASSIFICATION 
# . BINARY CROSS ENTROPY LOSS 
# . LOG LOSS
